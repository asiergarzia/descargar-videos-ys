# %%
import requests
import re
from bs4 import BeautifulSoup
import subprocess
import os
import glob
import sys


# Especifica las extensiones de los archivos que quieres eliminar
extensions = ['*.m3u8', '*.m3u']
for extension in extensions:
    # Busca todos los archivos con la extensión especificada
    files_to_delete = glob.glob(extension)
    for file_name in files_to_delete:
        # Si existe, elimínalo
        os.remove(file_name)
        print(f"Archivo {file_name} eliminado.")
base = "https://www.machogaytube.com"
base = input(f"introduce una web, por ejemplo: {base} \n") or "https://www.machogaytube.com"
print(f"La web ingresada es: {base}")

menu = ["/categories/", "/channels/", "/pornstars/"]

while True:
    entrada = input("- categorias --> pulsa 1\n- canales --> pulsa 2\n- pornstars --> pulsa 3: \n")
    try:
        i = int(entrada) - 1
        if i in [0, 1, 2]:
            url = base+menu[i]
            print("has escogido : " + menu[i])
            break
        else:
            print("Por favor, introduce 1, 2 o 3.")
    except ValueError:
        print("Por favor, introduce un número.")


print(f"Configurada la que url de la que se extraerán los videos.\nEs:\n- {base}")
try:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
except requests.RequestException as e:
    print(f"Error al solicitar la URL {url}: {e}")
    sys.exit(1)

categorias = []
if i==0:
	buscar = "/category/"
elif i==1:
    buscar = "/channels/"
else:
    buscar = "/pornstar/"
for link in soup.find_all('a'):
	href = link.get('href')
	
	if href and href.startswith(buscar):
		categorias.append(href[10:])
for categoria in categorias:
	print(categorias.index(categoria)+1,"-", categoria)
numero=1
numerotxt = input("Escoge una categoria: \n")
varios = []
for posicion in numerotxt:
	if posicion == ",":
		varios = numerotxt.split(",")
		break
if len(varios) < 1:   
	varios.append(numerotxt)
print("longitud varios: ",len(varios)) 
for v in varios:    
	n = int(v)-1
	print(f"Se descargaran los videos de la categoria: {categorias[n]}")
	cate = categorias[n]
	url = base+buscar+categorias[n]
	print(url)
	response2 = requests.get(url)
	soup2 = BeautifulSoup(response2.text, 'html.parser')
	enlaces= []
	fileout = f"machogaytube_{cate}.txt"
	for link in soup2.find_all('a'):
		href = link.get('href')
		if href and href.startswith('/movies/'):
			enlaces.append(href)
	with open(fileout, 'w') as f_output:
		for enlace in enlaces:
			print(base+enlace+"\n")
			f_output.write(base+enlace+"\n")
	comando = f"youtube-dl -i -g -a {fileout} > {fileout}.m3u8"
	resultado = subprocess.run(comando, shell=True, capture_output=True, text=True)
	if resultado.returncode == 0:
		print("El comando se ejecutó correctamente:")
		print(resultado.stdout)
	else:
		print("Se produjo un error al ejecutar el comando:")
		print(resultado.stderr)
# Out:
# Archivo machogaytube_pissing.txt.m3u8 eliminado.
# introduce una web, por ejemplo: https://www.machogaytube.com
#
# La web ingresada es: https://www.machogaytube.com
# - categorias --> pulsa 1
# - canales --> pulsa 2
# - pornstars --> pulsa 3:
# 4
# Por favor, introduce 1, 2 o 3.
# - categorias --> pulsa 1
# - canales --> pulsa 2
# - pornstars --> pulsa 3:
# 5
# Por favor, introduce 1, 2 o 3.
# - categorias --> pulsa 1
# - canales --> pulsa 2
# - pornstars --> pulsa 3:
# e
# Por favor, introduce un número.
# - categorias --> pulsa 1
# - canales --> pulsa 2
# - pornstars --> pulsa 3:
# 1
# has escogido : /categories/
# Configurada la que url de la que se extraerán los videos.
# Es:
# - https://www.machogaytube.com
# 1 - pissing
# 2 - first-time
# 3 - gloryhole
# 4 - french
# 5 - old-and-young-18
# 6 - flashing
# 7 - monster
# 8 - cum-in-mouth
# 9 - danish
# 10 - straight
# 11 - penis
# 12 - russian
# 13 - domination
# 14 - creampie-compilation
# 15 - husband
# 16 - teen-18
# 17 - erotic
# 18 - daddy
# 19 - old-man
# 20 - gangbang
# 21 - creampie
# 22 - caught
# 23 - 18
# 24 - spanking
# 25 - threesome
# 26 - blue-collars
# 27 - rough
# 28 - tall
# 29 - bareback
# 30 - voyeur
# 31 - hardcore
# 32 - muscle
# 33 - seduced
# 34 - bukkake
# 35 - toilet
# 36 - uncle
# 37 - mature
# 38 - army
# 39 - bbc
# 40 - fraternity
# 41 - massage
# 42 - selfsuck
# 43 - teacher
# 44 - cuckold
# 45 - bear
# 46 - swallow
# 47 - doctor
# 48 - bisexual
# 49 - car
# 50 - full-movie
# 51 - public
# 52 - stolen
# 53 - bdsm
# 54 - police
# 55 - jock
# 56 - compilation
# 57 - orgy
# 58 - homemade
# 59 - cousin
# 60 - tied
# 61 - tight
# 62 - pakistani
# 63 - screaming
# 64 - black
# 65 - hermaphrodite
# 66 - sauna
# 67 - big-cock
# 68 - thug
# 69 - crossdresser
# 70 - virgin
# 71 - extreme
# 72 - instruction
# 73 - double-penetration
# 74 - athlete
# 75 - big-ass
# 76 - ass-licking
# 77 - deepthroat
# 78 - mature-anal
# 79 - beach
# 80 - cinema
# 81 - swinger
# 82 - locker-room
# 83 - feet
# 84 - backroom
# 85 - wrestling
# 86 - twink
# 87 - group
# 88 - handjob-compilation
# 89 - club
# 90 - grandpa
# 91 - turkish
# 92 - humiliation
# 93 - taxi
# 94 - fat
# 95 - latino
# 96 - bondage
# 97 - fisting
# 98 - italian
# 99 - armpit
# 100 - orgasm-compilation
# 101 - surprise
# 102 - leather
# 103 - 3d
# 104 - asian
# 105 - uncut-dick
# 106 - strip
# 107 - ass-to-mouth
# 108 - sport-gear
# 109 - accident
# 110 - amateur
# 111 - reality
# 112 - outdoor
# 113 - midget
# 114 - shower
# 115 - solo
# 116 - prostate
# 117 - money
# 118 - underwear
# 119 - dance
# 120 - foursome
# 121 - whore
# 122 - trimmed
# 123 - jerking
# 124 - behind-the-scenes
# 125 - spy
# 126 - mexican
# 127 - dirty-talk
# 128 - vintage
# 129 - gym
# 130 - breeding
# 131 - sperm
# 132 - polish
# 133 - cowboy
# 134 - shaving
# 135 - toys
# 136 - hotel
# 137 - clothed
# 138 - interracial
# 139 - nudist
# 140 - contest
# 141 - hairy
# 142 - exam
# 143 - facial
# 144 - pornstar
# 145 - hunk
# 146 - masturbation
# 147 - anime
# 148 - korean
# 149 - thai
# 150 - ebony
# 151 - underwater
# 152 - 69
# 153 - nipples
# 154 - wet
# 155 - student
# 156 - suit-and-tie
# 157 - boots
# 158 - german
# 159 - funny
# 160 - uniform
# 161 - european
# 162 - beauty
# 163 - cumshot
# 164 - czech
# 165 - maid
# 166 - arab
# 167 - sissy
# 168 - train
# 169 - dress
# 170 - casting
# 171 - natural
# 172 - bedroom
# 173 - finnish
# 174 - greek
# 175 - sensual
# 176 - office
# 177 - skinny
# 178 - food
# 179 - dorm
# 180 - cumshot-compilation
# 181 - flexible
# 182 - neighbor
# 183 - tease
# 184 - indian
# 185 - sport
# 186 - farting
# 187 - redhead
# 188 - swedish
# 189 - spanish
# 190 - japanese
# 191 - bitch
# 192 - fetish
# 193 - piercing
# 194 - spandex
# 195 - footjob
# 196 - nylon
# 197 - picture-compilation
# 198 - farm
# 199 - roleplay
# 200 - handjob
# 201 - heels
# 202 - orgasm
# 203 - futanari
# 204 - cute
# 205 - bar
# 206 - parody
# 207 - dogging
# 208 - dildo
# 209 - kissing
# 210 - smoking
# 211 - african
# 212 - rimjob
# 213 - party
# 214 - portuguese
# 215 - cartoon
# 216 - audition
# 217 - strapon
# 218 - american
# 219 - blowjob
# 220 - balls
# 221 - college
# 222 - chinese
# 223 - socks
# 224 - skater
# 225 - ghetto
# 226 - pantyhose
# 227 - vibrator
# 228 - punk
# 229 - white
# 230 - gay
# 231 - satin
# 232 - cheating
# 233 - celebrity
# 234 - femdom
# 235 - bath
# 236 - brazil
# 237 - indonesian
# 238 - slovakian
# 239 - jeans
# 240 - bulgarian
# 241 - prison
# 242 - latex
# 243 - tattoo
# 244 - couple
# 245 - bus
# 246 - blonde
# 247 - anal
# 248 - dutch
# 249 - game
# 250 - serbian
# 251 - thong
# 252 - military
# 253 - machine
# 254 - lingerie
# 255 - british
# 256 - condom
# 257 - double-anal
# 258 - goth
# 259 - hot
# 260 - solarium
# 261 - electro
# 262 - ugly
# 263 - swimsuit
# 264 - huge-dildo
# 265 - close-up
# 266 - short-hair
# 267 - slovenian
# 268 - mask
# 269 - shy
# 270 - small-cock
# 271 - ass
# 272 - boyfriend
# 273 - pool
# 274 - classic
# 275 - gagging
# 276 - asshole
# 277 - bathroom
# 278 - blindfolded
# 279 - bottle
# 280 - bounded
# 281 - brunette
# 282 - chubby
# 283 - dark-hair
# 284 - emo
# 285 - facesitting
# 286 - filipino
# 287 - fingering
# 288 - girdle
# 289 - glasses
# 290 - gloves
# 291 - hungarian
# 292 - interview
# 293 - kitchen
# 294 - live-cam
# 295 - long-hair
# 296 - norwegian
# 297 - oil
# 298 - panties
# 299 - pov
# 300 - pump
# 301 - riding
# 302 - romanian
# 303 - rubber
# 304 - shoes
# 305 - stockings
# 306 - swiss
# 307 - webcam
